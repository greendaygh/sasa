# %%
a, b=input().split()
a=int(a)
b=int(b)
x=1
y=1

while a>=x and b>=y:
    if(b==y):
        print(x, y)
        y=1
        x+=1
    else:
        print(x, y)
        y+=1
# Out:
#  2 3
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
