# %%
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure()
fig.suptitle('No axes on this figure')
fig, ax_lst=plt.subplots(2,2)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure()
fig.suptitle('No axes on this figure')
fig, ax_lst=plt.subplots(1,)

# %%
x=np.linspace(0,100,1000)
plt.plot(x, x, label='linear')
plt.plot(x,x**2, label='cubic' )

# %%
x=np.arange(0, 10, 0.2)
y=np.cos(x)
fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig2 = plt.figure(figsize=(10,10))
ax2 = fig2.add_subplot(1,1,1)
# subplot을 행방향으로 1개, 열방향으로 1개 이중 1번째 subplot 
ax2.add_patch(
     patches.Rectangle(
        (0.65, 0.75),
        0.1,
        0.1,
        color='c'
        #색에서 k가 검정, b 파랑, g 초록, c 청록(시앙!), m 마젠타, r 빨강, w 흰색, y 노란(?)색, 
     ) )

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
fig2 = plt.figure(figsize=(10,10))
ax2 = fig2.add_subplot(1,1,1)
class Part:
    def __init__(self, id, seq, name, type) :
        self.id= id
        self.seq= seq
        self.name= name
        self.type= type
        self.location = ""
    def show_sequence(self):
        print(self.seq)
    def show_location(self):
        print(self.location)
class Circuit:
    def __init__(self, id, name, type):
        self.id=id
        self.name=name
        self.seq= ""
        self.type=type
        self.parts= []     
    def set_sequence(self):
        for p in self.parts:
            self.seq+=p.seq
    def show_sequence(self):
        print(self.seq)
    def show_parts(self):
        for p in self.parts:
            print(p.name)
    def set_parts(self, parts):
        self.parts = parts
    def set_location(self):
        l=1
        for p in self.parts:
                p.location = l
                l+=len(p.seq)
    def show_sequence(self):
        x=0
        for i in acircuit.parts: 
             show_gene(i.type, len(i.seq), x/10)
             x+=len(i.seq)/10
            
def show_gene(typ, leng, location):
    if typ=='Promoter':
        ax2.add_patch(
        patches.Rectangle(
        (location, 0.2),
        int(leng)/100,
        0.4,
        color='c'
        #색에서 k가 검정, b 파랑, g 초록, c 청록(시앙!), m 마젠타, r 빨강, w 흰색, y 노란(?)색, 
        ) )
    if typ=='RBS':
        ax2.add_patch(
        patches.Rectangle(
        (location, 0.2),
        int(leng)/100,
        0.2,
        color='m'
        #색에서 k가 검정, b 파랑, g 초록, c 청록(시앙!), m 마젠타, r 빨강, w 흰색, y 노란(?)색, 
        ) )
    if typ=='CDS':
        ax2.add_patch(
        patches.Rectangle(
        (location, 0.2),
        int(leng)/100,
        0.2,
        color='y'
        #색에서 k가 검정, b 파랑, g 초록, c 청록(시앙!), m 마젠타, r 빨강, w 흰색, y 노란(?)색, 
        ) )
    if typ=='Terminator':
        ax2.add_patch(
        patches.Rectangle(
        (location, 0.2 ),
        int(leng)/100,
        0.2,
        color='g'
        #색에서 k가 검정, b 파랑, g 초록, c 청록(시앙!), m 마젠타, r 빨강, w 흰색, y 노란(?)색, 
        ) )
apro=Part(1, "AGC", "Ap", "Promoter")
arbs=Part(2, "TTG", "Ar", "RBS")
acds=Part(3, "ACC", "Ac", "CDS")
brbs=Part(4, "CCC", "Bc", "CDS")
crbs=Part(6, "TAG", "Cr", "RBS")
bcds=Part(7, "ATC", "Bc", "CDS")
drbs=Part(8, "CTC", "Dc", "CDS")
ater=Part(9, "ATT", "At", "Terminator")
acircuit=Circuit(1, "circuit A", "biosensor")
acircuit.set_parts([apro, arbs, acds, apro, arbs, acds,acds,brbs,crbs, bcds, drbs,brbs,crbs, bcds, drbs, ater])
acircuit.set_sequence()
acircuit.show_sequence()
